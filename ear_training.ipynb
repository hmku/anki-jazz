# %%
# !apt-get install -y fluidsynth
# !pip install midiutil
# !pip install midi2audio
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: midiutil in /home/hku/.local/lib/python3.10/site-packages (1.2.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: midi2audio in /home/hku/.local/lib/python3.10/site-packages (0.1.1)

# %%
import base64
import os

import requests
from midiutil import MIDIFile
from tqdm.notebook import tqdm

# %%
# Paths
midi_dir = "jazz-midi"
os.makedirs(midi_dir, exist_ok=True)

soundfont_path = "FluidR3_GM.sf2"

output_dir = "jazz-audio"
os.makedirs(output_dir, exist_ok=True)

# %%
# NOTE: the open voicings are not just [x if x > k else x+12 for x in closed]
# because the 9 can either be in the same octave or an octave up. Similarly,
# some closed chords have the 3 and others have the 15. I still think I could
# have done something smarter here, but whatever
voicings = {
    "Maj7_closed": [0, 4, 11],
    "7_closed": [0, 4, 10],
    "m7_closed": [0, 3, 10],
    "Maj6_closed": [0, 4, 9, 11],
    "69_closed": [0, 4, 9, 14],
    "Maj9_closed": [0, 4, 11, 14],
    "9_closed": [0, 4, 10, 14],
    "m9_closed": [0, 3, 10, 14],
    "7b9_closed": [0, 4, 10, 13],
    "7#9_closed": [0, 4, 10, 15],
    "7#11_closed": [0, 4, 6, 10],
    "7b13_closed": [0, 4, 8, 10],
    "7add13_closed": None,  # [0, 4, 9, 10], (rarely voiced this way)
    "13_closed": [0, 4, 9, 10, 14],
    "7alt_closed": [0, 4, 8, 10, 15],
    "Maj7_open": [0, 11, 16],
    "7_open": [0, 10, 16],
    "m7_open": [0, 10, 15],
    "Maj6_open": [0, 11, 16, 21],
    "69_open": [0, 9, 14, 16],
    "Maj9_open": [0, 11, 14, 16],
    "9_open": [0, 10, 14, 16],
    "m9_open": [0, 10, 14, 15],
    "7b9_open": [0, 10, 13, 16],
    "7#9_open": None,  # [0, 10, 15, 16] (rarely voiced this way)
    "7#11_open": [0, 10, 16, 18],
    "7b13_open": [0, 10, 16, 20],
    "7add13_open": [0, 10, 16, 21],
    "13_open": [0, 10, 14, 16, 21],
    "7alt_open": None,  # [0, 10, 15, 16, 20] (rarely voiced this way)
    "dim_closed": [0, 3, 6, 9],
    "dim_clopen": [0, 6, 9, 15],
    "dim_open": [0, 9, 15, 18],
    "hdim_closed": [0, 3, 6, 10],
    "hdim_clopen": [0, 6, 10, 15],
    "hdim_open": [0, 10, 15, 18],  # same as m7b13
}

for voicing, offsets in voicings.items():
    if offsets is not None and voicing.endswith("closed"):
        open_offsets = voicings[voicing.replace("closed", "open")]
        if open_offsets is not None:
            for x in open_offsets:
                assert (
                    x in offsets or x - 12 in offsets
                ), f"Open/close voicing disagree for {voicing}, {offsets}"

roots = {
    "C": 0,
    "Db": 1,
    "D": 2,
    "Eb": 3,
    "E": 4,
    "F": 5,
    "Gb": 6,
    "G": 7,
    "Ab": 8,
    "A": -3,
    "Bb": -2,
    "B": -1,
}

chord_voicings = {
    f"{root}{voicing}": [
        48 + root_offset
        # make non-root notes an octave higher for closed voicings
        + (
            voicing_offset + 12
            if (voicing_offset != 0 and "closed" in voicing)
            else voicing_offset
        )
        for voicing_offset in voicing_offsets
    ]
    for voicing, voicing_offsets in voicings.items()
    for root, root_offset in roots.items()
    if voicing_offsets is not None
}


def create_midi_file(name, notes, velocity=128, duration=3, bpm=120):
    midi = MIDIFile(1)
    track = 0
    lead_in_time = 0.25  # add a 0.25 beat (1/2 second at 120bpm) delay
    midi.addTempo(track, time=0, tempo=bpm)
    for note in notes:
        midi.addNote(
            track,
            channel=0,
            pitch=note,
            time=lead_in_time,
            duration=duration,
            volume=velocity,
        )
    filepath = os.path.join(midi_dir, f"{name}.mid")
    with open(filepath, "wb") as f:
        midi.writeFile(f)


for name, notes in tqdm(chord_voicings.items()):
    create_midi_file(name, notes)
# Out:
#   0%|          | 0/396 [00:00<?, ?it/s]

# %%
import multiprocessing
from midi2audio import FluidSynth

def midi_to_wav(filename):
    midi_path = os.path.join(midi_dir, filename)
    wav_path = os.path.join(output_dir, filename.replace(".mid", ".wav"))

    # Each process creates its own FluidSynth instance
    fs = FluidSynth(soundfont_path)
    fs.midi_to_audio(midi_path, wav_path)

if __name__ == "__main__":
    files = [filename for filename in os.listdir(midi_dir) if filename.endswith(".mid")]
    with multiprocessing.Pool() as pool:
        pool.map(midi_to_wav, files)
# Out:
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AMaj7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ahdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7#9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AbMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ahdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abhdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AMaj9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7b9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab69_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AbMaj7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A69_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Am7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abhdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AMaj9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AbMaj7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7b9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7b9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab69_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A69_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Am7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abhdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7b9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AbMaj9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7#11_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7#11_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Am9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb69_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abm7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbhdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7b9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AbMaj9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7#11_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7#11_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb69_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Am9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abm7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbhdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7b9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B69_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7b9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Adim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7#9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7#9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7#11_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AMaj6_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abm9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbhdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7b9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B69_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Adim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7#11_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abm9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbm7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7#11_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Adim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/A7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AMaj7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb7#9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/AbMaj6_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbm7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/B7#11_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Abdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bb9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ahdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ab7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BMaj6_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbm9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C69_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7b9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Chdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D7#9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/CMaj7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Dbm9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7#11_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bbm9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Chdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/CMaj9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Dbdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Dbm9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bhdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BMaj7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7#11_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BbMaj6_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Cm7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/CMaj9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Dbdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/DbMaj6_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BbMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7#9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bhdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BMaj7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Cm7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Dbdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/DbMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BbMaj7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bhdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BMaj9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Cm9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Dbhdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db69_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db7b9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/DbMaj7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BbMaj7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BMaj9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bm7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Cdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Cm9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D69_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D7b9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Dbhdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db69_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db7b9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/DbMaj7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BbMaj9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bm7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Cdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/CMaj6_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D69_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/D7b9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Dbhdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db7#11_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Db7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/DbMaj9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Cdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/BbMaj9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/CMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/C13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Bm9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# ...
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7#11_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gm7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/FMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7#11_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GbMaj9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbm7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7#11_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gm9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/FMaj7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7#11_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbm7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7#9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gm9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/FMaj7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7#9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbm9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GMaj6_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/FMaj9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7add13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbm9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/FMaj9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7alt_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ghdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GbMaj6_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GMaj7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7b13_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GbMaj6_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ghdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GMaj7_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb69_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7b13_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbhdim_clopen.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Ghdim_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GbMaj7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7b9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GMaj9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb69_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G7b9_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/G69_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gbhdim_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gb7b9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/Gm7_closed.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GMaj9_open.wav'..
# FluidSynth runtime version 2.2.5
# Copyright (C) 2000-2022 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'jazz-audio/GbMaj7_open.wav'..

# %%
import os
import base64
import requests
import multiprocessing
from functools import partial

# CONFIG
deck_name = "jazz-v2"
media_folder = "jazz-audio"
anki_connect_url = "http://172.20.160.1:8765"

# Step 1: Create the deck
def create_deck(name):
    requests.post(
        anki_connect_url,
        json={"action": "createDeck", "version": 6, "params": {"deck": name}},
    )

# Step 2: Prepare the note payload (done in parallel)
def prepare_note_payload(filename):
    audio_path = os.path.join(media_folder, filename)
    with open(audio_path, "rb") as f:
        audio_data = f.read()
        encoded_audio = base64.b64encode(audio_data).decode("utf-8")
    return {
        "filename": filename,
        "encoded": encoded_audio,
        "back": os.path.splitext(filename)[0]
    }

# Step 3: Send to Anki (sequentially, safer)
def send_to_anki(note):
    filename = note["filename"]
    encoded_audio = note["encoded"]
    back = note["back"]

    # Upload audio
    requests.post(
        anki_connect_url,
        json={
            "action": "storeMediaFile",
            "version": 6,
            "params": {"filename": filename, "data": encoded_audio},
        },
    )

    # Add note
    requests.post(
        anki_connect_url,
        json={
            "action": "addNote",
            "version": 6,
            "params": {
                "note": {
                    "deckName": deck_name,
                    "modelName": "Basic",
                    "fields": {
                        "Front": f"[sound:{filename}]",
                        "Back": back,
                    },
                    "options": {"allowDuplicate": False},
                    "tags": ["jazz-audio"],
                }
            },
        },
    )
    print(f"Added {filename}")

# MAIN
if __name__ == "__main__":
    create_deck(deck_name)

    # Get relevant files
    files = [
        f for f in os.listdir(media_folder)
        if f.lower().endswith((".mp3", ".wav", ".ogg"))
    ]

    # Prepare notes using multiprocessing
    with multiprocessing.Pool() as pool:
        notes = pool.map(prepare_note_payload, files)

    # Send notes to Anki (sequential to avoid AnkiConnect issues)
    for note in notes:
        send_to_anki(note)

    print("✅ Done!")
# Out:
# Added A13_closed.wav
# Added A13_open.wav
# Added A69_closed.wav
# Added A69_open.wav
# Added A7#11_closed.wav
# Added A7#11_open.wav
# Added A7#9_closed.wav
# Added A7add13_open.wav
# Added A7alt_closed.wav
# Added A7b13_closed.wav
# Added A7b13_open.wav
# Added A7b9_closed.wav
# Added A7b9_open.wav
# Added A7_closed.wav
# Added A7_open.wav
# Added A9_closed.wav
# Added A9_open.wav
# Added Ab13_closed.wav
# Added Ab13_open.wav
# Added Ab69_closed.wav
# Added Ab69_open.wav
# Added Ab7#11_closed.wav
# Added Ab7#11_open.wav
# Added Ab7#9_closed.wav
# Added Ab7add13_open.wav
# Added Ab7alt_closed.wav
# Added Ab7b13_closed.wav
# Added Ab7b13_open.wav
# Added Ab7b9_closed.wav
# Added Ab7b9_open.wav
# Added Ab7_closed.wav
# Added Ab7_open.wav
# Added Ab9_closed.wav
# Added Ab9_open.wav
# Added Abdim_clopen.wav
# Added Abdim_closed.wav
# Added Abdim_open.wav
# Added Abhdim_clopen.wav
# Added Abhdim_closed.wav
# Added Abhdim_open.wav
# Added Abm7_closed.wav
# Added Abm7_open.wav
# Added Abm9_closed.wav
# Added Abm9_open.wav
# Added AbMaj6_closed.wav
# Added AbMaj6_open.wav
# Added AbMaj7_closed.wav
# Added AbMaj7_open.wav
# Added AbMaj9_closed.wav
# Added AbMaj9_open.wav
# Added Adim_clopen.wav
# Added Adim_closed.wav
# Added Adim_open.wav
# Added Ahdim_clopen.wav
# Added Ahdim_closed.wav
# Added Ahdim_open.wav
# Added Am7_closed.wav
# Added Am7_open.wav
# Added Am9_closed.wav
# Added Am9_open.wav
# Added AMaj6_closed.wav
# Added AMaj6_open.wav
# Added AMaj7_closed.wav
# Added AMaj7_open.wav
# Added AMaj9_closed.wav
# Added AMaj9_open.wav
# Added B13_closed.wav
# Added B13_open.wav
# Added B69_closed.wav
# Added B69_open.wav
# Added B7#11_closed.wav
# Added B7#11_open.wav
# Added B7#9_closed.wav
# Added B7add13_open.wav
# Added B7alt_closed.wav
# Added B7b13_closed.wav
# Added B7b13_open.wav
# Added B7b9_closed.wav
# Added B7b9_open.wav
# Added B7_closed.wav
# Added B7_open.wav
# Added B9_closed.wav
# Added B9_open.wav
# Added Bb13_closed.wav
# Added Bb13_open.wav
# Added Bb69_closed.wav
# Added Bb69_open.wav
# Added Bb7#11_closed.wav
# Added Bb7#11_open.wav
# Added Bb7#9_closed.wav
# Added Bb7add13_open.wav
# Added Bb7alt_closed.wav
# Added Bb7b13_closed.wav
# Added Bb7b13_open.wav
# Added Bb7b9_closed.wav
# Added Bb7b9_open.wav
# Added Bb7_closed.wav
# Added Bb7_open.wav
# Added Bb9_closed.wav
# Added Bb9_open.wav
# Added Bbdim_clopen.wav
# Added Bbdim_closed.wav
# Added Bbdim_open.wav
# Added Bbhdim_clopen.wav
# Added Bbhdim_closed.wav
# Added Bbhdim_open.wav
# Added Bbm7_closed.wav
# Added Bbm7_open.wav
# Added Bbm9_closed.wav
# Added Bbm9_open.wav
# Added BbMaj6_closed.wav
# Added BbMaj6_open.wav
# Added BbMaj7_closed.wav
# Added BbMaj7_open.wav
# Added BbMaj9_closed.wav
# Added BbMaj9_open.wav
# Added Bdim_clopen.wav
# Added Bdim_closed.wav
# Added Bdim_open.wav
# Added Bhdim_clopen.wav
# Added Bhdim_closed.wav
# Added Bhdim_open.wav
# Added Bm7_closed.wav
# Added Bm7_open.wav
# Added Bm9_closed.wav
# Added Bm9_open.wav
# Added BMaj6_closed.wav
# Added BMaj6_open.wav
# Added BMaj7_closed.wav
# Added BMaj7_open.wav
# Added BMaj9_closed.wav
# Added BMaj9_open.wav
# Added C13_closed.wav
# Added C13_open.wav
# Added C69_closed.wav
# Added C69_open.wav
# Added C7#11_closed.wav
# Added C7#11_open.wav
# Added C7#9_closed.wav
# Added C7add13_open.wav
# Added C7alt_closed.wav
# Added C7b13_closed.wav
# Added C7b13_open.wav
# Added C7b9_closed.wav
# Added C7b9_open.wav
# Added C7_closed.wav
# Added C7_open.wav
# Added C9_closed.wav
# Added C9_open.wav
# Added Cdim_clopen.wav
# Added Cdim_closed.wav
# Added Cdim_open.wav
# Added Chdim_clopen.wav
# Added Chdim_closed.wav
# Added Chdim_open.wav
# Added Cm7_closed.wav
# Added Cm7_open.wav
# Added Cm9_closed.wav
# Added Cm9_open.wav
# Added CMaj6_closed.wav
# Added CMaj6_open.wav
# Added CMaj7_closed.wav
# Added CMaj7_open.wav
# Added CMaj9_closed.wav
# Added CMaj9_open.wav
# Added D13_closed.wav
# Added D13_open.wav
# Added D69_closed.wav
# Added D69_open.wav
# Added D7#11_closed.wav
# Added D7#11_open.wav
# Added D7#9_closed.wav
# Added D7add13_open.wav
# Added D7alt_closed.wav
# Added D7b13_closed.wav
# Added D7b13_open.wav
# Added D7b9_closed.wav
# Added D7b9_open.wav
# Added D7_closed.wav
# Added D7_open.wav
# Added D9_closed.wav
# Added D9_open.wav
# Added Db13_closed.wav
# Added Db13_open.wav
# Added Db69_closed.wav
# Added Db69_open.wav
# Added Db7#11_closed.wav
# Added Db7#11_open.wav
# Added Db7#9_closed.wav
# Added Db7add13_open.wav
# Added Db7alt_closed.wav
# Added Db7b13_closed.wav
# Added Db7b13_open.wav
# Added Db7b9_closed.wav
# Added Db7b9_open.wav
# Added Db7_closed.wav
# Added Db7_open.wav
# Added Db9_closed.wav
# Added Db9_open.wav
# Added Dbdim_clopen.wav
# Added Dbdim_closed.wav
# Added Dbdim_open.wav
# Added Dbhdim_clopen.wav
# Added Dbhdim_closed.wav
# Added Dbhdim_open.wav
# Added Dbm7_closed.wav
# Added Dbm7_open.wav
# Added Dbm9_closed.wav
# Added Dbm9_open.wav
# Added DbMaj6_closed.wav
# Added DbMaj6_open.wav
# Added DbMaj7_closed.wav
# Added DbMaj7_open.wav
# Added DbMaj9_closed.wav
# Added DbMaj9_open.wav
# Added Ddim_clopen.wav
# Added Ddim_closed.wav
# Added Ddim_open.wav
# Added Dhdim_clopen.wav
# Added Dhdim_closed.wav
# Added Dhdim_open.wav
# Added Dm7_closed.wav
# Added Dm7_open.wav
# Added Dm9_closed.wav
# Added Dm9_open.wav
# Added DMaj6_closed.wav
# Added DMaj6_open.wav
# Added DMaj7_closed.wav
# Added DMaj7_open.wav
# Added DMaj9_closed.wav
# Added DMaj9_open.wav
# Added E13_closed.wav
# Added E13_open.wav
# Added E69_closed.wav
# Added E69_open.wav
# Added E7#11_closed.wav
# Added E7#11_open.wav
# Added E7#9_closed.wav
# Added E7add13_open.wav
# Added E7alt_closed.wav
# Added E7b13_closed.wav
# Added E7b13_open.wav
# Added E7b9_closed.wav
# Added E7b9_open.wav
# Added E7_closed.wav
# Added E7_open.wav
# Added E9_closed.wav
# Added E9_open.wav
# Added Eb13_closed.wav
# Added Eb13_open.wav
# Added Eb69_closed.wav
# Added Eb69_open.wav
# Added Eb7#11_closed.wav
# Added Eb7#11_open.wav
# Added Eb7#9_closed.wav
# Added Eb7add13_open.wav
# Added Eb7alt_closed.wav
# Added Eb7b13_closed.wav
# Added Eb7b13_open.wav
# Added Eb7b9_closed.wav
# Added Eb7b9_open.wav
# Added Eb7_closed.wav
# Added Eb7_open.wav
# Added Eb9_closed.wav
# Added Eb9_open.wav
# Added Ebdim_clopen.wav
# Added Ebdim_closed.wav
# Added Ebdim_open.wav
# Added Ebhdim_clopen.wav
# Added Ebhdim_closed.wav
# Added Ebhdim_open.wav
# Added Ebm7_closed.wav
# Added Ebm7_open.wav
# Added Ebm9_closed.wav
# Added Ebm9_open.wav
# Added EbMaj6_closed.wav
# Added EbMaj6_open.wav
# Added EbMaj7_closed.wav
# Added EbMaj7_open.wav
# Added EbMaj9_closed.wav
# Added EbMaj9_open.wav
# Added Edim_clopen.wav
# Added Edim_closed.wav
# Added Edim_open.wav
# Added Ehdim_clopen.wav
# Added Ehdim_closed.wav
# Added Ehdim_open.wav
# Added Em7_closed.wav
# Added Em7_open.wav
# Added Em9_closed.wav
# Added Em9_open.wav
# Added EMaj6_closed.wav
# Added EMaj6_open.wav
# Added EMaj7_closed.wav
# Added EMaj7_open.wav
# Added EMaj9_closed.wav
# Added EMaj9_open.wav
# Added F13_closed.wav
# Added F13_open.wav
# Added F69_closed.wav
# Added F69_open.wav
# Added F7#11_closed.wav
# Added F7#11_open.wav
# Added F7#9_closed.wav
# Added F7add13_open.wav
# Added F7alt_closed.wav
# Added F7b13_closed.wav
# Added F7b13_open.wav
# Added F7b9_closed.wav
# Added F7b9_open.wav
# Added F7_closed.wav
# Added F7_open.wav
# Added F9_closed.wav
# Added F9_open.wav
# Added Fdim_clopen.wav
# Added Fdim_closed.wav
# Added Fdim_open.wav
# Added Fhdim_clopen.wav
# Added Fhdim_closed.wav
# Added Fhdim_open.wav
# Added Fm7_closed.wav
# Added Fm7_open.wav
# Added Fm9_closed.wav
# Added Fm9_open.wav
# Added FMaj6_closed.wav
# Added FMaj6_open.wav
# Added FMaj7_closed.wav
# Added FMaj7_open.wav
# Added FMaj9_closed.wav
# Added FMaj9_open.wav
# Added G13_closed.wav
# Added G13_open.wav
# Added G69_closed.wav
# Added G69_open.wav
# Added G7#11_closed.wav
# Added G7#11_open.wav
# Added G7#9_closed.wav
# Added G7add13_open.wav
# Added G7alt_closed.wav
# Added G7b13_closed.wav
# Added G7b13_open.wav
# Added G7b9_closed.wav
# Added G7b9_open.wav
# Added G7_closed.wav
# Added G7_open.wav
# Added G9_closed.wav
# Added G9_open.wav
# Added Gb13_closed.wav
# Added Gb13_open.wav
# Added Gb69_closed.wav
# Added Gb69_open.wav
# Added Gb7#11_closed.wav
# Added Gb7#11_open.wav
# Added Gb7#9_closed.wav
# Added Gb7add13_open.wav
# Added Gb7alt_closed.wav
# Added Gb7b13_closed.wav
# Added Gb7b13_open.wav
# Added Gb7b9_closed.wav
# Added Gb7b9_open.wav
# Added Gb7_closed.wav
# Added Gb7_open.wav
# Added Gb9_closed.wav
# Added Gb9_open.wav
# Added Gbdim_clopen.wav
# Added Gbdim_closed.wav
# Added Gbdim_open.wav
# Added Gbhdim_clopen.wav
# Added Gbhdim_closed.wav
# Added Gbhdim_open.wav
# Added Gbm7_closed.wav
# Added Gbm7_open.wav
# Added Gbm9_closed.wav
# Added Gbm9_open.wav
# Added GbMaj6_closed.wav
# Added GbMaj6_open.wav
# Added GbMaj7_closed.wav
# Added GbMaj7_open.wav
# Added GbMaj9_closed.wav
# Added GbMaj9_open.wav
# Added Gdim_clopen.wav
# Added Gdim_closed.wav
# Added Gdim_open.wav
# Added Ghdim_clopen.wav
# Added Ghdim_closed.wav
# Added Ghdim_open.wav
# Added Gm7_closed.wav
# Added Gm7_open.wav
# Added Gm9_closed.wav
# Added Gm9_open.wav
# Added GMaj6_closed.wav
# Added GMaj6_open.wav
# Added GMaj7_closed.wav
# Added GMaj7_open.wav
# Added GMaj9_closed.wav
# Added GMaj9_open.wav
# ✅ Done!
